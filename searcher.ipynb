# %% [markdown]
# در این سند قصد داریم چند به چهار شیوه‌ی متفاوت اطلاعات را بازیابی کنیم و روی آنها جستجو انجام بدهیم.

# %% [markdown]
# ابتدا قسمت های مشترک هر چهار شیوه را وارد می‌کنیم:

# %%
! pip install fasttext
! pip install sentence_transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fasttext in /home/mohammad/.local/lib/python3.8/site-packages (0.9.2)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/lib/python3/dist-packages (from fasttext) (45.2.0)
# Requirement already satisfied: pybind11>=2.2 in /home/mohammad/.local/lib/python3.8/site-packages (from fasttext) (2.10.0)
# Requirement already satisfied: numpy in /home/mohammad/.local/lib/python3.8/site-packages (from fasttext) (1.22.4)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sentence_transformers
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Collecting huggingface-hub>=0.4.0
#   Using cached huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
# Requirement already satisfied: scikit-learn in /home/mohammad/.local/lib/python3.8/site-packages (from sentence_transformers) (1.1.1)
# Requirement already satisfied: numpy in /home/mohammad/.local/lib/python3.8/site-packages (from sentence_transformers) (1.22.4)
# Requirement already satisfied: nltk in /home/mohammad/.local/lib/python3.8/site-packages (from sentence_transformers) (3.3)
# Collecting transformers<5.0.0,>=4.6.0
#   Using cached transformers-4.21.0-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: tqdm in /home/mohammad/.local/lib/python3.8/site-packages (from sentence_transformers) (4.64.0)
# Requirement already satisfied: scipy in /home/mohammad/.local/lib/python3.8/site-packages (from sentence_transformers) (1.8.1)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.96-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting torchvision
#   Using cached torchvision-0.13.0-cp38-cp38-manylinux1_x86_64.whl (19.1 MB)
# Collecting torch>=1.6.0
#   Using cached torch-1.12.0-cp38-cp38-manylinux1_x86_64.whl (776.3 MB)
# Requirement already satisfied: packaging>=20.9 in /home/mohammad/.local/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (21.3)
# Collecting filelock
#   Using cached filelock-3.7.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (5.3.1)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.22.0)
# Collecting typing-extensions>=3.7.4.3
#   Using cached typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: regex!=2019.12.17 in /home/mohammad/.local/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.4.24)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Using cached tokenizers-0.12.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from nltk->sentence_transformers) (1.14.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/mohammad/.local/lib/python3.8/site-packages (from scikit-learn->sentence_transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mohammad/.local/lib/python3.8/site-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/lib/python3/dist-packages (from torchvision->sentence_transformers) (7.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/mohammad/.local/lib/python3.8/site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence_transformers) (3.0.9)
# Installing collected packages: tokenizers, sentencepiece, typing-extensions, filelock, torch, huggingface-hub, transformers, torchvision, sentence_transformers
# Successfully installed filelock-3.7.1 huggingface-hub-0.8.1 sentence_transformers-2.2.2 sentencepiece-0.1.96 tokenizers-0.12.1 torch-1.12.0 torchvision-0.13.0 transformers-4.21.0 typing-extensions-4.3.0

# %%
from commons.documents_reader import get_documents
from commons.hazm_tokenizer import HazmTokenizer
from searchers.fasttext_searcher import FasttextSearcher
from searchers.tfidf_searcher import TfidfSearcher
from searchers.transformer_searcher import TransformerSearcher

# %% [markdown]
# حال تمام متون پردازشی و تمام متن های جستجویی را می‌خوانیم:

# %%
documents = get_documents()

queries = open('queries.txt').readlines()

# %% [markdown]
# تابع زیر یک جستجوگر و تعدادی متن جستوجویی به عنوان ورودی می‌گیرد و بعد از انجام جستجو نتیجه‌ی آن را چاپ می‌کند:

# %%
def search_queries_by_searcher(test_searcher, test_queries):
    test_searcher.add_documents(documents)
    for query in test_queries:
        print("Query:")
        print(query)

        print("Results:")
        result = test_searcher.search(query)
        for doc in result:
            print(doc.id + ": " + doc.content[:120].replace('\n', ''))

# %% [markdown]
# حال پیاده سازی هر چهار تا کلاس را در نظر بگیرید:

# %%
import fasttext
from scipy import spatial
from commons.document import Document
import pandas
from hazm import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sentence_transformers import SentenceTransformer, util


class BooleanSearcher:
    def __init__(self, tokenizer):
        self.tokenizer = tokenizer
        self.documents_by_tokens = {}

    def add_documents(self, documents):
        for document in documents:
            self.__add_document(document)

    def __add_document(self, document):
        tokens = self.tokenizer.tokenize(document.content)
        for token in tokens:
            if not self.documents_by_tokens.__contains__(token):
                self.documents_by_tokens[token] = set()
            self.documents_by_tokens[token].add(document.id)

    def get_included_documents_set(self, token):
        if self.documents_by_tokens.__contains__(token):
            return self.documents_by_tokens[token]
        else:
            return set()

    def search(self, query_text, result_limit=10):
        query_tokens = self.tokenizer.tokenize(query_text)
        query_tokens_included_sets = [self.get_included_documents_set(qt) for qt in query_tokens]
        result_doc_ids = list(set.intersection(*query_tokens_included_sets)) + \
                         list(set.union(*query_tokens_included_sets))
        result_doc_ids = result_doc_ids[:result_limit]
        return [Document.get_document_by_id(doc_id) for doc_id in result_doc_ids]
    

class FasttextSearcher:
    def __init__(self):
        self.model = fasttext.load_model(
            '/home/mohammad/Desktop/Advanced_Information_Retrieval/hw3/hw3_project/fasttext_model/mmd-model.bin')
        self.vector_by_document = {}

    def add_documents(self, documents):
        for document in documents:
            content = document.content.replace('\n', ' ')
            self.vector_by_document[document.id] = self.model.get_sentence_vector(content)

    def search(self, query_text, result_limit=10):
        query_text = query_text.replace('\n', ' ')
        query_vector = self.model.get_sentence_vector(query_text)
        distances = []
        for doc_id, doc_vector in self.vector_by_document.items():
            distances.append((doc_id, 1 - spatial.distance.cosine(query_vector, doc_vector)))
        distances.sort(key=lambda x: x[1], reverse=True)
        return [Document.get_document_by_id(item[0]) for item in distances[:min(result_limit, len(distances))]]

    

class TfidfSearcher:
    def __init__(self):
        self.tf_idf_vector_maker = TfidfVectorizer(norm='l2', tokenizer=word_tokenize)
        self.data_frame = None
        self.query_tokenize = None
        self.documents = None

    def add_documents(self, documents):
        self.documents = documents
        contents = [doc.content for doc in documents]
        tf_idf = self.tf_idf_vector_maker.fit_transform(contents)
        self.data_frame = pandas.DataFrame(tf_idf.todense(), columns=self.tf_idf_vector_maker.get_feature_names_out())
        self.query_tokenize = self.tf_idf_vector_maker.build_tokenizer()

    def search(self, query_text, result_limit=10):
        query_tokens = self.query_tokenize(query_text)
        query_data_frame = self.data_frame[query_tokens].copy()
        query_data_frame.loc[:, "sum"] = query_data_frame.sum(axis=1).array
        result = query_data_frame.nlargest(result_limit, "sum")
        return [self.documents[i] for i in result.index]


    
class TransformerSearcher:
    def __init__(self):
        self.model = SentenceTransformer('all-MiniLM-L6-v2')
        self.vector_by_document = {}

    def add_documents(self, documents):
        for document in documents:
            self.vector_by_document[document.id] = self.model.encode(document.content)

    def search(self, query_text, result_limit=10):
        query_vector = self.model.encode(query_text)
        distances = []
        for doc_id, doc_vector in self.vector_by_document.items():
            distances.append((doc_id, util.cos_sim(query_vector, doc_vector)))
        distances.sort(key=lambda x: x[1], reverse=True)
        return [Document.get_document_by_id(item[0]) for item in distances[:min(result_limit, len(distances))]]

# %% [markdown]
# ابتدا boolean را آزمایش می‌کنیم:

# %%
tokenizer = HazmTokenizer()
searcher = BooleanSearcher(tokenizer)
search_queries_by_searcher(searcher, queries[:5])
# Out:
# Query:
# بازسازي شهر زلزله زده بم
#
# Results:
# HAM2-821014-108.ham: رئيس مجلس در بمبه گزارش خبرنگار پارلماني ايسنا، حجت  الاسلام والمسلمين مهدي كروبي كه به منظور بازديد از مناطق زلزله زد
# HAM2-821018-127.ham: در نشست با وزير فرهنگ و ارشاد اسلامي پيشنهاد شد؛برنامه هاي جامعه فرهنگي و هنري براي كمك به مردم مناطق  زلزله زدهبنيا
# HAM2-830707-090.ham: گله شهردار بم از روند بازسازي اين شهرايسنا: مردم بم وضع معيشتي مناسبي ندارند و جيره غذايي متعلق به آنان فقط در دو ماهه
# HAM2-821108-102.ham: بم در بلاتكليفيشوراي شهر و شهرداري تهران خدمات رساني به بم را گسترش مي دهندگروه شهري: اعضاي شوراي شهر و مسئولان شهرد
# HAM2-831005-128.ham: يك سال پس از زلزلهزندگي با اميدمديريت شهري تهران برنامه اردوهاي دانش آموزي بم را استمرار بخشند تا به سهم خود بتوانند
# HAM2-821014-070.ham: شمار تلفات زلزله بم حدود 35 هزار نفر برآورد شدجانشين فرماندهي لشكر 41 ثارالله و جانشين قرارگاه عملياتي قدس نيروي زميني
# HAM2-830430-112.ham: رئيس مجمع تشخيص مصلحت نظام:بازسازي بم بايد براي آيندگان الگو شودكرمان - خبرگزاري جمهوري اسلامي: رئيس  مجمع  تشخيص  م
# HAM2-830129-085.ham: گزارش هيأت اعزامي مجلس از مشكلات زلزله زدگان بممخبر كميسيون اصل نود مجلس شوراي اسلامي گزارش بازديد هيأتي از اين كميسيو
# HAM2-821016-081.ham: ساخت شش اردوگاه براي اسكان موقت زلزله زدگان بممعاون  امنيتي  و انتظامي وزارت  كشور اعلام  كرد: 6 اردوگاه  براي اسكان
# HAM2-830122-130.ham: وزير مسكن و شهرسازي: مقدمات عمليات بازسازي شهرستان بم فراهم شده استوزير مسكن  و شهرسازي  اعلام  كرد: مقدمات  لازم  برا
# Query:
# برگزيدگان جشنواره فيلم فجر
#
# Results:
# HAM2-851114-001.ham: جشنواره 25 با شوك آغاز شدسلحشوران عاشورايي جشنواره فيلم را افتتاح كردندگروه ادب و هنر- بيست و پنجمين جشنواره فيلم فج
# HAM2-831117-034.ham: كافه ترانزيت فيلم برگزيده تماشاگران جشنوارهفيلم  سينمايي  كافه  ترانزيت  ساخته  كامبوزيا پرتوي  در صدر برگزيدگان روز س
# HAM2-850226-116.ham: سينماي ايرانفيلم هاي ايراني بازار كن در يك كتابكتاب راهنماي فيلم هاي ايراني حاضر در بازار فيلم جشنواره كن 2006 از سو
# HAM2-851125-002.ham: برگزيدگان بخش جنبي جشنواره  فيلم فجر معرفي شدندگروه ادب و هنر- در مراسم اهداي جوايز بخش جنبي جشنواره فيلم فجر دو فيلم
# HAM2-851124-001.ham: در آيين اختتاميه جشنواره فيلم فجرتالار وحدت هم اعتراض به داوري ها را شنيدعكس: محمد توكليگروه ادب و هنر- بيست و پنج
# HAM2-841204-070.ham: سينماي ايرانخاتمي به تماشاي به نام پدر نشستسيد محمد خاتمي، سه شنبه شب به تماشاي «به نام پدر» آخرين ساخته ابراهيم حات
# HAM2-850621-025.ham: اهالي سينما از جشن سينماي ايران مي گوينداسكار به سبك ايرانيقناعت پيشگي هميشه هم خوب نيست!چگونه مي شود جشن سينماي ا
# HAM2-840919-121.ham: چه فيلم هايي به جشنواره 24 مي رسنددر راه جشنوارهجشنواره بين المللي فيلم فجر مهم ترين رويداد سينمايي ايران، امسال 12
# HAM2-841206-025.ham: كوتاه از هفت هنرتعطيلي بزرگداشت ها - برنامه بزرگداشت آثار برگزيده جشنواره فجر در موزه سينما با اعلام عزاي عمومي در كشو
# HAM2-841109-022.ham: جشنواره فيلم فجر به پايان رسيدايسنا: حسين صفارهرندي، وزير فرهنگ و ارشاد اسلامي، در آيين پاياني بيست وچهارمين جشنواره ف
# Query:
# علل مرگ و مير نهنگ ها
#
# Results:
# HAM2-821125-004.ham: شبكه آزمايشگاههاي ملي توسعه در گفت وگو با مدير كل دفتر پشتيباني پژوهشي وزارت علومنظمي با نام شامتكالهام رضاخانياشا
# HAM2-851111-103.ham: تازه ترين اظهارنظر رئيس جمهوري آمريكابوش: از كجا معلوم ايران سلاح اتمي داشته باشد؟مخالفت آمريكا با پيشنهاد البرادعي
# HAM2-820715-063.ham: نيروي انتظامي با برهم زنندگان تجمعات قانوني برخورد مي كندقاليباف: در دوره مديريت من 94 درصد تجمعات قانوني با امنيت كام
# HAM2-841201-181.ham: نگاهي به بحث احياي امور تربيتي، اين بار از زاويه اي ديگرنه تربيتي، نه تربيت بدني- معاونت فوق برنامهابراهيم اصلانيد
# HAM2-840418-052.ham: افت شاخص ها در پايان هفته بورسگروه بورس: شاخص هاي اصلي عملكرد بازار سهام تهران در پايان هفته گذشته افتي دوباره را تجرب
# HAM2-831115-109.ham: تفهيم قتل غيرعمد به مدير عامل يك كارخانهگروه حوادث: مديرعامل يك كارخانه سيمان سازي به دليل مرگ دلخراش كارگر آن كارخانه
# HAM2-840615-042.ham: حجم بازارگرداني در بورس افزايش يافتگروه بورس: حجم بازارگرداني طي معاملات ديروز بورس تهران به شدت افزايش يافت.به گزار
# HAM2-840501-123.ham: نگاه امروزارزش منطقسهند صادقي بهمنيخصومت سخت و آشتي ناپذير غزالي با فلسفه چنان بود كه تحصيل فلسفه را حرام مي دانست
# HAM2-821228-075.ham: فاجعه معمارياين همه سخت دردناك و غيرقابل تحمل بود، وقتي عروس دو هزار ساله خشتي جهان لرزيد و فروريخت،  همانقدر كه از دس
# HAM2-840825-079.ham: هشدار به افراد سيگاري در حال تركپك  عميق به سيگار ممنوعگروه دانش و فناوري ـ مرتضي اسلام زاده: مجله معتبر انجمن پزشكي
# Query:
# راه هاي جلو گيري از ابتلا به ديابت
#
# Results:
# HAM2-821125-004.ham: شبكه آزمايشگاههاي ملي توسعه در گفت وگو با مدير كل دفتر پشتيباني پژوهشي وزارت علومنظمي با نام شامتكالهام رضاخانياشا
# HAM2-851111-103.ham: تازه ترين اظهارنظر رئيس جمهوري آمريكابوش: از كجا معلوم ايران سلاح اتمي داشته باشد؟مخالفت آمريكا با پيشنهاد البرادعي
# HAM2-820715-063.ham: نيروي انتظامي با برهم زنندگان تجمعات قانوني برخورد مي كندقاليباف: در دوره مديريت من 94 درصد تجمعات قانوني با امنيت كام
# HAM2-840418-052.ham: افت شاخص ها در پايان هفته بورسگروه بورس: شاخص هاي اصلي عملكرد بازار سهام تهران در پايان هفته گذشته افتي دوباره را تجرب
# HAM2-840501-123.ham: نگاه امروزارزش منطقسهند صادقي بهمنيخصومت سخت و آشتي ناپذير غزالي با فلسفه چنان بود كه تحصيل فلسفه را حرام مي دانست
# HAM2-821228-075.ham: فاجعه معمارياين همه سخت دردناك و غيرقابل تحمل بود، وقتي عروس دو هزار ساله خشتي جهان لرزيد و فروريخت،  همانقدر كه از دس
# HAM2-840825-079.ham: هشدار به افراد سيگاري در حال تركپك  عميق به سيگار ممنوعگروه دانش و فناوري ـ مرتضي اسلام زاده: مجله معتبر انجمن پزشكي
# HAM2-850616-136.ham: گفت وگو با سردار بهمن كارگر معاون وظيفه عمومي ناجاغايبان سربازي و كابوسي تازهاسماعيل رمضاني ـ كامران بارنجياز بيرو
# HAM2-840909-039.ham: بهارستانصفت چاكرانعارفي گفت: رفتم در گلخني تا دلم بگشايد، كه گريزگاه بعضي اوليا بوده است. ديدم رئيس گلخن را شاگردي ب
# HAM2-820812-140.ham: سايه روشن ورزشكميته ملي المپيك و شوراي برون مرزي سازمان ورزشمعراج مژده - سازمان تربيت بدني تاكيد مي كند كه كسب
# Query:
# انتخاب سرمربي تيم ملي فوتبال ايران
#
# Results:
# HAM2-820830-061.ham: خبرهاي كوتاهاسامي  تيم هاي  راه يافته  به  مرحله  نهايي  جام  ملت هاي  اروپا16 تيم  اروپايي  حاضر در مرحله  نهايي  ج
# HAM2-830116-062.ham: مايلي كهن: تاريخ انقضا بهار 83مايلي كهن نمونه كامل مربي اي است كه به تيم ها تحميل مي شود. كارنامه او در مقام يك مربي ب
# HAM2-820421-065.ham: مرگِ انگيزه به شيوه فوتبالدور نماي ليگ را ترسيم كنيمامير قلعه نويي پرچمدار مربيان جوانپس از كش و قوس هاي فراوان و
# HAM2-840606-122.ham: رئيس كميته ملي المپيك: بازيهاي تيم ملي ضعيف بوده استتماشاگران و رسانه هاي ما قدرت تحليل بالايي دارندخبرنگار همشهري:
# HAM2-820413-057.ham: اخبار كوتاهسرمربي جديد به پرسپوليس مي آيدپروين فقط مدير فني استمديرعامل باشگاه پرسپوليس تهران گفت: «علي پروي
# HAM2-840627-139.ham: تيم المپيك و حس مالكيتامير بهادري نژاداغلب كشورهاي جهان در كنار برخورداري از سازمان ورزش، از تشكيلاتي با عنوان كميته
# HAM2-820713-109.ham: سايه روشن ورزشتربيت پزشك تيم در ايرانوزارت بهداشت با پيشنهاد برگزاري دوره «تربيت پزشك تيم» از سوي فدراسيون جهاني پزش
# HAM2-831015-147.ham: اولين ستاد ياري به فوتبالفوتبال و گروه كارشناسان در فدراسيونتيم ملي فعلي ايران بازيكنان شاخص و در استانداردهاي جهاني
# HAM2-850501-098.ham: جلال طالبي:اطراف تيم ملي كمي شلوغ استايسنا: سرمربي سابق تيم ملي فوتبال ايران معتقد است كه در دعوت از بازيكنان بايد م
# HAM2-831212-140.ham: گفت وگوي همشهري با مربي جديد تيم ملي ب ايرانحمايت «ب» از «الف»مهر داد اولادي و فرزاد مجيدي از جمله بازيكنان آينده دا

# %% [markdown]
# حال نوبت tfidf است:

# %%
searcher = TfidfSearcher()
search_queries_by_searcher(searcher, queries[:5])
# Out:
# Query:
# بازسازي شهر زلزله زده بم
#
# Results:
# HAM2-831002-023.ham: گردهمايي معماران در واشنگتنبم جديد را چگونه بسازيم- afp در آستانه سالگرد زلزله ويرانگر بم، معماران و كارشناسان به ام
# HAM2-830506-029.ham: بازسازي شهر بم؛ فرصت ها و تهديدهابا توجه به ضعف و ناكارآيي دانش مربوط به بازسازي در كشور ما و نيز اقداماتي كه تاكنون د
# HAM2-831005-128.ham: يك سال پس از زلزلهزندگي با اميدمديريت شهري تهران برنامه اردوهاي دانش آموزي بم را استمرار بخشند تا به سهم خود بتوانند
# HAM2-821010-030.ham: بازسازي بمبا آنكه شاد باش گفتن به شهروندان بمي در حال كنون بي معنا به نظر مي رسد، اما به هر حال بازسازي اين شهر مي توا
# HAM2-831001-076.ham: در گفت وگوي اختصاصي همشهري با مهندس سعيدي كياجزئيات آخرين برنامه هاي ستاد بازسازي بم تشريح شدرضايت مردم، هويت تاريخي
# HAM2-831003-183.ham: مهندس محمد سعيدي كيا مسئول بازسازي بم در گفت وگو با همشهريكارنامه بازسازي بمدرفرودگاه بم شرط گذاشت:«اگر مي خواهيد مص
# HAM2-831002-077.ham: مراحل بازسازي ارگ بم تا چهار سال ديگر به پايان مي رسدفارس: مدير ميراث فرهنگي و گردشگري استان كرمان گفت: كارهاي پژوهشي
# HAM2-821028-021.ham: احداث شهر بم در محل فعلي آنمعاون اداري، مالي و برنامه ريزي استانداري كرمان گفته است كه شهر بم در محل فعلي آن احداث خوا
# HAM2-830310-039.ham: اينجابازار بم احيا مي شود5 ماه زمان زيادي نيست كه يك فاجعه را از ذهن بيرون كنيم. هنوز هم گاهي مي شنويم كه قرار است ب
# HAM2-831010-163.ham: حضرت  آيت الله خامنه اي:بم بايد به گونه اي ساخته شود كه جلوه اي از زيبايي، سنت و استحكام گرددفارس: رهبر معظم انقلاب
# Query:
# برگزيدگان جشنواره فيلم فجر
#
# Results:
# HAM2-820927-069.ham: 70 درخواست براي حضور در جشنواره فيلم فجردرخواست شركت 70 عنوان فيلم به دفتر جشنواره فيلم فجر رسيد.به گزارش ايسنا به ن
# HAM2-840807-033.ham: جشنواره فيلم فجر 30 دي ماه آغاز مي شودگروه ادب و هنر: بيست و چهارمين جشنواره بين المللي فيلم فجر از سي ام دي ماه تا ده
# HAM2-811126-084.ham: سخن نخستجشنواره فيلم فجر و مديريت سينماي ايرانعليرضا محموديبيست و يكمين جشنواره فيلم فجر به پايان رسيد. با يك نگاه
# HAM2-831008-031.ham: چند خبر كوتاه از فجراما آخرين خبرها از جشنواره فيلم فجر حاكي است كه تاكنون حضور 46 كشور جهان در اين جشنواره مشخص شده.
# HAM2-850906-025.ham: نگاهچند نكته درباره جشنواره فيلم فجرده روز شگفت انگيزسعيد مروتي1)جشنواره فيلم فجر، مهمترين ويترين سينماي ايران در سا
# HAM2-850930-025.ham: آسيب شناسي سينماي امروز ايران- نگاهي به جشنواره فيلم فجر(گذشته و امروز)تحقق يك جشنواره معتبر داخليسعيد مستغاثيشبهه
# HAM2-811102-008.ham: حاشيه هنر* پركارترين فيلمبرداران جشنواره محمد آلادپوش فيلمبردار با سابقه سينما كه اين روزها مشغول فيلمبرداري فيلم گا
# HAM2-851017-021.ham: سايه روشنتحقق يك جشنواره معتبر جهاني سيد محسن هاشميپيش از هر چيز نخست بايد از بنيان گذاران جشنواره فيلم فجر ياد و ست
# HAM2-831009-041.ham: برنامه هاي جشنواره بين المللي فيلم فجر اعلام شددبير بيست و سومين جشنواره بين المللي فيلم فجر، شناسايي نقاط قوت و ضعف س
# HAM2-840919-121.ham: چه فيلم هايي به جشنواره 24 مي رسنددر راه جشنوارهجشنواره بين المللي فيلم فجر مهم ترين رويداد سينمايي ايران، امسال 12
# Query:
# علل مرگ و مير نهنگ ها
#
# Results:
# HAM2-830603-037.ham: شكار نهنگ از ديرباز تا امروزتجارت خونينزه بدن حيوان را مي شكافد و 40 دقيقه زجرآور طول مي كشد تا حيوان جان سپارد؛ اين
# HAM2-840406-030.ham: گذرگاهدهن كجي ژاپني ها به حافظان طبيعتبا وجودي كه كميسيون بين المللي صيد نهنگ مخالفت شديد خود را با صيد دو برابر نهن
# HAM2-840226-056.ham: حوادث رانندگي اصلي ترين علت مرگ و مير در كشورگروه اجتماعي: آمار تلفات ناشي از تصادفات در كشور در حال افزايش است به طور
# HAM2-821129-044.ham: قتل عام در ژاپنسرخي دريا از خون دلفين هاستگوشت دلفين و نهنگ در ژاپن به عنوان يك غذاي لذيذ تلقي شده و بيش از ساير نقا
# HAM2-811027-008.ham: تصويب طرح خروج معتادان از ندامتگاه هاآيين نامه انتقال زندان ها به خارج از شهر تقديم هيات دولت شده است رئيس سازمان زن
# HAM2-850914-031.ham: جهان سلامتايدز سومين قاتل دنياگروه سلامت- دكتر سيدمحمد ابوترابي: در آستانه روز جهاني ايدز، سازمان بهداشت جهاني گزارش
# HAM2-840702-068.ham: كنترل فشار خونگروه دانش و فناوري ـ ذوالفقار دانشي نسب: استفاده تركيبي از داروهاي كنترل فشار خون و كلسترول، مي تواند سا
# HAM2-830423-130.ham: بيماري هاي قلبي علت مرگ 35 درصد جوانان تهرانيبراساس آمار ارائه شده از سوي سازمان بهشت زهرا(س)، دومين عامل مرگ جوانان ب
# HAM2-811114-033.ham: آيا مراد متكلم فهم شدهروح الله يوسفي اگر پذيرفته باشيم _ كه 1 معنايي و مرادي در هر كلامي الزاما نهفته است _ و 2 متكل
# HAM2-850508-028.ham: در پي نامه 156 نماينده براي تامين اعتبار كاهش تصادفات جاده اي، همشهري بررسي مي كندايران رتبه اول در تصادفات جاده ايگ
# Query:
# راه هاي جلو گيري از ابتلا به ديابت
#
# Results:
# HAM2-850507-021.ham: دريچهفست فودهاو ابتلا به ديابتسميه شرافتي- ديابت چهارمين علت مرگ ومير در بيشتر كشورهاي در حال توسعه است.طبق برآورد
# HAM2-830825-082.ham: هشدار:24 ميليون جمعيت كشور مستعد ابتلا به ديابت هستندگروه اجتماعي: در حالي كه بيماري ديابت به عنوان عارضه پنهان همرا
# HAM2-840823-061.ham: بي خوابي ابتلا به ديابت را 5 برابر مي كندايلنا: اختلال در مدت زمان خواب احتمال ابتلا به بيماري هاي ديابت را در مردان ا
# HAM2-850301-104.ham: ديابت، پيشگيري يا درمانقند دردسرسازسميه شرافتيديابت يك بيماري مزمن و شايع است كه گسترش آن منجر به از دست رفتن حدود
# HAM2-820814-048.ham: 4 ميليون ايراني به ديابت مبتلا هستندرئيس انجمن بيماران ديابتي اعلام كرد: 5 درصد مردم در كشور يعني 4حدود ميليون نفر مبت
# HAM2-821202-019.ham: آهن زياد و ابتلا به ديابتآخرين بررسي هاي پزشكي از رابطه مستقيم وجود آهن زياد در خون زنان و ميزان ابتلا به بيماري ديابت
# HAM2-830729-015.ham: سيب زميني، بارداري و ديابتنتايج تحقيقات جديد دانشمندان استراليايي نشان مي دهد كه مصرف زياد سيب زميني توسط زنان باردار
# HAM2-830122-016.ham: چرا مردم اين همه گرفتار ديابت مي شوندبسياري از افراد چاق  در برابر انسولين مقاومت ندارند و تمام كساني كه در برابر انسو
# HAM2-830421-001.ham: 70 درصد جامعه در خطر ابتلا  به ديابتقند خونتان را دائم كنترل كنيدآذر ديوسالاررشد روزافزون علم و دستيابي بشر به ناش
# HAM2-830117-018.ham: وزن زياد كودكان و ابتلا به ديابتاضافه وزن در كودكان، آنها را مستعد ابتلا به ديابت در بزرگسالي مي كند.ميزان ابتلا به
# Query:
# انتخاب سرمربي تيم ملي فوتبال ايران
#
# Results:
# HAM2-830413-069.ham: ... در حاشيهپايان عمر داوري كولينا در جهان فوتبالگروه ورزشي: «پير لوييجي كولينا» داور بين المللي فوتبال ايتالي
# HAM2-830521-091.ham: برانكو ايوانكوويچ در ملاقات با مهرعليزادهزبان مشترك بين كادر فني تيم ملي و مربيانگروه ورزشي: نشست مشترك مهندس محسن م
# HAM2-831212-140.ham: گفت وگوي همشهري با مربي جديد تيم ملي ب ايرانحمايت «ب» از «الف»مهر داد اولادي و فرزاد مجيدي از جمله بازيكنان آينده دا
# HAM2-820602-063.ham: علي پروين سرمربي تيم ملي فوتبال مي شود؟20 روز مهلت براي استخدام مربي خارجيگروه ورزشي: علي كفاشيان معاون سازمان تربيت
# HAM2-840606-122.ham: رئيس كميته ملي المپيك: بازيهاي تيم ملي ضعيف بوده استتماشاگران و رسانه هاي ما قدرت تحليل بالايي دارندخبرنگار همشهري:
# HAM2-830512-092.ham: ايران شاهكار بزرگي در فينالي زودرس خلق كردگروه ورزشي:تيم ملي ايران در فينالي زودرس برابر تيم چهارم جهان، يك شاهكار بزر
# HAM2-840508-128.ham: سرمربي تيم ملي فوتبال:بازگشت به ايران بهترين تصميم بودگروه ورزشي: سرمربي تيم ملي فوتبال مي گويد: بازگشت زود هنگام تي
# HAM2-831015-147.ham: اولين ستاد ياري به فوتبالفوتبال و گروه كارشناسان در فدراسيونتيم ملي فعلي ايران بازيكنان شاخص و در استانداردهاي جهاني
# HAM2-850311-120.ham: مجيد جلالي هدايت تيم فوتبال پاس را به عهده گرفتسرمربي سابق تيم فوتبال پاس تهران پس از دو فصل دوري از اين تيم مجددا هدا
# HAM2-841027-127.ham: تيم ملي و اميد اوكراين در تهراننگاه كلان فدراسيون به تيم هاي ملي فوتبالگروه ورزشي: دهم اسفندماه تيم ملي اوكراين به ا

# %% [markdown]
# برای fasttext ابتدا یک مدل مخصوص برای داده‌های خودمان باید train کنیم و با این اجرای ساده آن را انجام دادیم:

# %%
from commons.documents_reader import get_documents

current_path = '/home/mohammad/Desktop/Advanced_Information_Retrieval/hw3/hw3_project/fasttext_model'

all_contents_file_path = current_path + '/all_contents.txt'
with open(all_contents_file_path, 'w') as file:
    for document in documents:
        file.write(document.content)

model = fasttext.train_supervised(all_contents_file_path)
model.save_model(current_path + '/mmd-model.bin')

# %% [markdown]
# حال آن را آزمایش می‌کنیم:

# %%
searcher = FasttextSearcher()
search_queries_by_searcher(searcher, queries[:5])
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# Query:
# بازسازي شهر زلزله زده بم
#
# Results:
# HAM2-821014-059.ham: كلاف كشي  بناي ارگدر پي مجروح شدن افشين ابراهيمي مدير پايگاه پژوهشي ارگ بم كه در زلزله اخير بم اتفاق افتاده و مصوبات س
# HAM2-821226-026.ham: معجزه هزار واحديبايد به وزارت مسكن و شهرسازي ماشاءالله بگوييم تا چشم نخورد. قرار است پس از 3 ماه از گذشت زلزله بم، عمل
# HAM2-831205-110.ham: نشست مطبوعاتي باشگاه استقلال امروز برگزار مي شودگروه ورزشي: در آستانه دربي پايتخت، نشست مطبوعاتي باشگاه استقلال امروز
# HAM2-850330-106.ham: برنامه بازيهاي امروزساعت 30/17 آلمان _ اكوادورساعت 30/17 لهستان _ كاستاريكاساعت 30/22 انگليس _ سوئدساعت30/22پارا
# HAM2-821028-021.ham: احداث شهر بم در محل فعلي آنمعاون اداري، مالي و برنامه ريزي استانداري كرمان گفته است كه شهر بم در محل فعلي آن احداث خوا
# HAM2-830730-081.ham: توسط مجمع تشخيص مصلحت نظامسياست هاي بخش گردشگري بررسي مي شودايرنا:معاون  رييس  جمهور و رييس  سازمان  ميراث  فرهنگي
# HAM2-820814-056.ham: بزرگترين  دايرةالمعارف  نهج البلاغه  در نمايشگاه  قرآن  عرضه  شدگروه علمي فرهنگي: بزرگترين  دايرة المعارف  نهج البلاغه
# HAM2-831227-121.ham: هاشمي رفسنجاني امروز از بم ديدن مي كندفارس: امروز در سفري يك روزه رئيس مجمع تشخيص مصلحت نظام به استان كرمان سفر مي كند
# HAM2-830310-039.ham: اينجابازار بم احيا مي شود5 ماه زمان زيادي نيست كه يك فاجعه را از ذهن بيرون كنيم. هنوز هم گاهي مي شنويم كه قرار است ب
# HAM2-820821-035.ham: با حضور  رئيس جمهوري انجام شدتجليل از خادمان قرآنگروه علمي فرهنگي: دهمين  دوره  انتخاب  خادمان  برگزيده  قرآن  كريم
# Query:
# برگزيدگان جشنواره فيلم فجر
#
# Results:
# HAM2-840807-033.ham: جشنواره فيلم فجر 30 دي ماه آغاز مي شودگروه ادب و هنر: بيست و چهارمين جشنواره بين المللي فيلم فجر از سي ام دي ماه تا ده
# HAM2-821125-085.ham: فيلم اينترنشنالسي وهشتمين مجله انگليسي زبان فيلم اينترنشنال با برگزاري بيست و دومين جشنواره بين المللي فيلم فجر منتشر
# HAM2-820927-069.ham: 70 درخواست براي حضور در جشنواره فيلم فجردرخواست شركت 70 عنوان فيلم به دفتر جشنواره فيلم فجر رسيد.به گزارش ايسنا به ن
# HAM2-831008-031.ham: چند خبر كوتاه از فجراما آخرين خبرها از جشنواره فيلم فجر حاكي است كه تاكنون حضور 46 كشور جهان در اين جشنواره مشخص شده.
# HAM2-831108-062.ham: 3 فيلم جديد در جشنواره فجرخبرگزاري فارس: سه فيلم به فيلم هاي شركت كننده در بخش مسابقه سينماي ايران، خارج از مسابقه و م
# HAM2-820806-027.ham: فهرست كدهاي tld
# HAM2-840804-039.ham: فيلم ايراني برگزيده جشنواره اديان ايتاليافيلم «اينجا چراغي روشن است» به كارگرداني رضا ميركريمي جايزه بهترين فيلم جشنوا
# HAM2-821022-061.ham: بهروز افخميخبر رسيدن «گاوخوني» به جشنواره فجر از سال گذشته به گوش مي رسيد. آخرين اثر افخمي قرار بود يك فيلم جمع وجور و
# HAM2-841108-020.ham: شبكه خبر سياست هاي سينماي ايران را تحليل مي كندايسنا: شبكه خبر در برنامه گزارش فرهنگي و هنري خود درباره جشنواره فيلم ف
# HAM2-831124-054.ham: برگزيدگان بخش جنبي جشنوارهدر مراسم اختتاميه بخش جنبي بيست و سومين جشنواره بين المللي فيلم فجر كه صبح چهارشنبه 21 بهمن
# Query:
# علل مرگ و مير نهنگ ها
#
# Results:
# HAM2-830610-073.ham: شبكه گردشگري ميراث فرهنگي افتتاح شدهمزمان با خجسته  سالروز ميلاد امير مؤمنان حضرت علي(ع)شبكه اطلاع رساني گردشگري خبرگز
# HAM2-811112-024.ham: به دنبال زمان گمشدهنگاه منتقدشادمهر راستين بالاخره انتظارها به سر آمد و جشنواره فيلم فجر تصميم گرفت به روشي متمايز
# HAM2-840624-170.ham: سخنگوي وزارت خارجه جنايت هولناك كاظمين را محكوم كردمهر: سخنگوي وزارت امور خارجه جنايت هولناك روز گذشته در عراق را كه م
# HAM2-850421-090.ham: تشكيل كميسيون هاي رسيدگي به گردشگريايلنا: رئيس سازمان ميراث فرهنگي و گردشگري خراسان جنوبي، گفت: كميسيون هاي تخصصي با ه
# HAM2-820224-054.ham: مترو به تجريش مي رسداجرا ي20 طرح ترافيكي در شمال تهرانگروه شهري: به منظور روان سازي توام با ايمني تردد وسايل نقليه ب
# HAM2-840714-043.ham: همايش اسطوره هاي ايراني و ادبيات كودك برگزار مي شودمهر:همزمان با دومين نمايشگاه ايران شناسي، همايش اسطوره هاي ايراني و
# HAM2-840608-158.ham: مسابقات بوكس قهرماني آسيا - ويتنامفرج زاده صعود كرد، ارمشي حذف شدنخستين روز از بيست و سومين دوره مسابقات بوكس قهرمان
# HAM2-851021-006.ham: اخبار كوتاهكارگاه پست مدرنيزم - كارگاه پست مدرنيزم و نئواكسپرسيونيزم در مجموعه هنرپژوهي نقش جهان برگزار مي شود.اين ك
# HAM2-831227-097.ham: افزايش وام قرض الحسنه جوانان تا سقف 10 ميليون ريالگروه اجتماعي: بيست و دومين جلسه شوراي عالي جوانان كشور به رياست حجت
# HAM2-830518-014.ham: دانشگاه مازندران* تاريخچه: با ادغام مدرسه عالي علوم اقتصادي و اجتماعي بابلسر، دانشسراي عالي فني بابل، مدرسه عالي كشاور
# Query:
# راه هاي جلو گيري از ابتلا به ديابت
#
# Results:
# HAM2-820903-110.ham: الوطن ادعا كردپيام رساني اردن ميان ايران و آمريكاروزنامه الوطن به نقل از منابع اردني نوشت: ملك عبدالله دوم درصدد انت
# HAM2-830729-014.ham: كوري قابل پيشگيريموسسه ملي كهنسالي آمريكا اعلام كرد كه بسياري از نابينايي هايي كه به دليل بالا رفتن سن ايجاد مي شوند ق
# HAM2-830422-007.ham: افزايش وزن ديابتي ها ممنوعمبتلايان به ديابت نوع 2 پيشرفته، مجبور به استفاده از انسولين جهت درمان هستند. استعمال انسولي
# HAM2-831017-040.ham: جعبهتقابل همنام ها در اهوازآخر هفته اي ديگر و برنامه هاي اين دو روز؛پنج شنبه: امروز ساعت 40:13 مي توانيد تكرار سري
# HAM2-850720-079.ham: غرب به شرق تونل رسالت مسدودمي شودايسنا: پليس راهنمايي و رانندگي تهران بزرگ از مسدود شدن غرب به شرق تونل رسالت خبر داد.
# HAM2-840823-061.ham: بي خوابي ابتلا به ديابت را 5 برابر مي كندايلنا: اختلال در مدت زمان خواب احتمال ابتلا به بيماري هاي ديابت را در مردان ا
# HAM2-850604-021.ham: پايان جنگ در بورس بيروتموج: بورس بيروت به آرامي از حاشيه جنگ بيرون مي آيد و نشانه هاي بهبود شرايط در آن آشكار مي شود.ب
# HAM2-851114-001.ham: جشنواره 25 با شوك آغاز شدسلحشوران عاشورايي جشنواره فيلم را افتتاح كردندگروه ادب و هنر- بيست و پنجمين جشنواره فيلم فج
# HAM2-850510-120.ham: احتمال پيوستن اشلي كول به رئال مادريدروزنامه اسپانيايي ماركا اعلام كرد احتمال پيوستن اشلي كول به رئال مادريد بسيار زيا
# HAM2-840409-002.ham: نرخ انواع لوازم نقاشي(قيمت ها به هزار ريال)
# Query:
# انتخاب سرمربي تيم ملي فوتبال ايران
#
# Results:
# HAM2-850420-085.ham: چشم اندازمتوسط مرگ و مير در تصادفات جاده اي ايران 10 برابر متوسط معمول جهاني است. تاكنون درباره زيادبودن تصادفات جاده
# HAM2-840219-030.ham: سخنراني درباره كتابها و كتابخانه هاي ديجيتالگروه علمي فرهنگي: كتابهاي ديجيتال و كتابخانه هاي ديجيتالي عنوان ميزگردي اس
# HAM2-840810-050.ham: برگزار ي جشن گلريزانگروه اجتماعي: ستاد احسان و نيكوكاري كميته امداد امام خميني(ره)پايگاه هاي ويژه كمك به آزادي زندانيا
# HAM2-830521-091.ham: برانكو ايوانكوويچ در ملاقات با مهرعليزادهزبان مشترك بين كادر فني تيم ملي و مربيانگروه ورزشي: نشست مشترك مهندس محسن م
# HAM2-830429-094.ham: هندبال باشگا ه هاي آسيادر سالن تازه تأسيس فدراسيونخبرنگارهمشهري: كنفدراسيون هندبال آسيا ميزباني هفتمين دوره مسابقات
# HAM2-840406-124.ham: تيم ملي بسكتبال امروز به بيروت مي رودگروه ورزشي: تيم ملي بسكتبال ايران براي شركت در مسابقات غرب آسيا(انتخاب جام ملت ها
# HAM2-830727-016.ham: فدراسيون فوتبال:خانه سازي ربطي به ما نداردبم پابه توپ مي شود!اينكه رئيس شوراي شهر بم عقيده دارد پول اين بازي مال آنه
# HAM2-820602-063.ham: علي پروين سرمربي تيم ملي فوتبال مي شود؟20 روز مهلت براي استخدام مربي خارجيگروه ورزشي: علي كفاشيان معاون سازمان تربيت
# HAM2-840928-035.ham: هيأت انتخاب فيلم هاي مستند جشنواره فجرگروه ادب و هنر: عليرضا رضاداد دبير بيست و چهارمين جشنواره بين المللي فيلم فجر طي
# HAM2-830228-089.ham: شهردار تهران:سوم خرداد قله دفاع مقدس ملت ايران استشهردار تهران، سوم خرداد سالروز آزادسازي خرمشهر را قله دفاع مقدس مل

# %% [markdown]
# در آخر transformer را آزمایش می‌کنیم:

# %%
searcher = TransformerSearcher()
search_queries_by_searcher(searcher, queries[:5])
# Out:
# Query:
# بازسازي شهر زلزله زده بم
#
# Results:
# HAM2-830120-086.ham: بهارستاناي گل بهار! اي شكوه زعفراناي گل نرگس!اي شبچراغ درخشان بر زر سرخ!اين چنين دردمندم رها مسازابونواس - ترج
# HAM2-831217-043.ham: بهارستاناهل دوزخ در دوزخ خوش تر باشند كه اندر دنيا، زيرا از حق با خبر باشند و در دنيا بي خبرند.فيه مافيه - مولوي
# HAM2-841207-097.ham: برداشت بعدي...!علي درويش* كسي كه به او «زياد برمي خورد» با ديگران «زياد برخورد مي كند»* براي «پيشرفت» بايد مدام «پ
# HAM2-821021-047.ham: حيات وحش ايران4 - يوزپلنگ آسيايي
# HAM2-841217-117.ham: نگاهفريد مرتضويورود و خروج پرندگان در استان سمنان به دليل عدم شيوع آنفولانزاي مرغي كنترل خواهد شد
# HAM2-841204-105.ham: برداشت بعدي...!-علي درويش* «محتاط باش، محتاج نباش».* راضي نشو، رازي از ديگران برملا كني.* وقتي «گوشي را مي كشي» پي
# HAM2-830116-094.ham: بهارستانبذار بارون ماچت كنهبذار بارون مث آبچك نقرهرو سرت چيكه كنهبذار بارون واست لالايي بگهلنگستون هيوز - ترجم
# HAM2-850429-097.ham: واگذاري مراكز تجاري برج ميلاد از ماه آيندهمدير عامل شركت يادمان سازه گفت: قرارداد واگذاري مراكز تجاري برج ميلاد به سرم
# HAM2-851013-010.ham: عكس روزعكس: رويترزموزه علوم و تكنولوژي شهر جينان، پايتخت ايالت شاندونگ چين همه روزه مراجعه كنندگان متعددي دارد. در ع
# HAM2-831005-038.ham: بهارستانحسن حبيب را ديد. گفت: اين درجه به چه يافتي؟گفت: بدان كه من دل سپيد مي كنم و تو كاغذ سياه مي كني.در ذكر حبي
# Query:
# برگزيدگان جشنواره فيلم فجر
#
# Results:
# HAM2-821021-047.ham: حيات وحش ايران4 - يوزپلنگ آسيايي
# HAM2-840409-002.ham: نرخ انواع لوازم نقاشي(قيمت ها به هزار ريال)
# HAM2-850429-097.ham: واگذاري مراكز تجاري برج ميلاد از ماه آيندهمدير عامل شركت يادمان سازه گفت: قرارداد واگذاري مراكز تجاري برج ميلاد به سرم
# HAM2-850809-009.ham: عكس روزعكس: مهر / باقر نصيرعلاقه مندان به رشته ورزشي موتورسواري در كوه هاي منطقه شميران تهران، با تجهيزات شخصي به اي
# HAM2-840416-147.ham: نگاهداوود كاظميدر صد بالايي از تصادفات به علت استفاده از تلفن همراه به هنگام رانندگي است.
# HAM2-830120-086.ham: بهارستاناي گل بهار! اي شكوه زعفراناي گل نرگس!اي شبچراغ درخشان بر زر سرخ!اين چنين دردمندم رها مسازابونواس - ترج
# HAM2-841217-117.ham: نگاهفريد مرتضويورود و خروج پرندگان در استان سمنان به دليل عدم شيوع آنفولانزاي مرغي كنترل خواهد شد
# HAM2-850720-008.ham: عكس روزعكس: رويترز / گوران توماسويچدو ماهيگير مصري كنار درياچه اي واقع در 210 كيلومتري شمال قاهره، روي قايق خود نماز
# HAM2-830513-045.ham: بهارستاناز نوازش جاودانه دستانت، اين خردينه دل مناز شادي،كرانه هايش را گم مي كندو ناگفتني را باز مي گويدرابيند
# HAM2-851013-010.ham: عكس روزعكس: رويترزموزه علوم و تكنولوژي شهر جينان، پايتخت ايالت شاندونگ چين همه روزه مراجعه كنندگان متعددي دارد. در ع
# Query:
# علل مرگ و مير نهنگ ها
#
# Results:
# HAM2-840409-002.ham: نرخ انواع لوازم نقاشي(قيمت ها به هزار ريال)
# HAM2-821021-047.ham: حيات وحش ايران4 - يوزپلنگ آسيايي
# HAM2-840416-147.ham: نگاهداوود كاظميدر صد بالايي از تصادفات به علت استفاده از تلفن همراه به هنگام رانندگي است.
# HAM2-831005-038.ham: بهارستانحسن حبيب را ديد. گفت: اين درجه به چه يافتي؟گفت: بدان كه من دل سپيد مي كنم و تو كاغذ سياه مي كني.در ذكر حبي
# HAM2-841217-117.ham: نگاهفريد مرتضويورود و خروج پرندگان در استان سمنان به دليل عدم شيوع آنفولانزاي مرغي كنترل خواهد شد
# HAM2-850429-097.ham: واگذاري مراكز تجاري برج ميلاد از ماه آيندهمدير عامل شركت يادمان سازه گفت: قرارداد واگذاري مراكز تجاري برج ميلاد به سرم
# HAM2-850809-009.ham: عكس روزعكس: مهر / باقر نصيرعلاقه مندان به رشته ورزشي موتورسواري در كوه هاي منطقه شميران تهران، با تجهيزات شخصي به اي
# HAM2-850720-008.ham: عكس روزعكس: رويترز / گوران توماسويچدو ماهيگير مصري كنار درياچه اي واقع در 210 كيلومتري شمال قاهره، روي قايق خود نماز
# HAM2-830120-086.ham: بهارستاناي گل بهار! اي شكوه زعفراناي گل نرگس!اي شبچراغ درخشان بر زر سرخ!اين چنين دردمندم رها مسازابونواس - ترج
# HAM2-830513-045.ham: بهارستاناز نوازش جاودانه دستانت، اين خردينه دل مناز شادي،كرانه هايش را گم مي كندو ناگفتني را باز مي گويدرابيند
# Query:
# راه هاي جلو گيري از ابتلا به ديابت
#
# Results:
# HAM2-831005-038.ham: بهارستانحسن حبيب را ديد. گفت: اين درجه به چه يافتي؟گفت: بدان كه من دل سپيد مي كنم و تو كاغذ سياه مي كني.در ذكر حبي
# HAM2-821021-047.ham: حيات وحش ايران4 - يوزپلنگ آسيايي
# HAM2-840416-147.ham: نگاهداوود كاظميدر صد بالايي از تصادفات به علت استفاده از تلفن همراه به هنگام رانندگي است.
# HAM2-840409-002.ham: نرخ انواع لوازم نقاشي(قيمت ها به هزار ريال)
# HAM2-850809-009.ham: عكس روزعكس: مهر / باقر نصيرعلاقه مندان به رشته ورزشي موتورسواري در كوه هاي منطقه شميران تهران، با تجهيزات شخصي به اي
# HAM2-850330-106.ham: برنامه بازيهاي امروزساعت 30/17 آلمان _ اكوادورساعت 30/17 لهستان _ كاستاريكاساعت 30/22 انگليس _ سوئدساعت30/22پارا
# HAM2-830513-045.ham: بهارستاناز نوازش جاودانه دستانت، اين خردينه دل مناز شادي،كرانه هايش را گم مي كندو ناگفتني را باز مي گويدرابيند
# HAM2-850720-008.ham: عكس روزعكس: رويترز / گوران توماسويچدو ماهيگير مصري كنار درياچه اي واقع در 210 كيلومتري شمال قاهره، روي قايق خود نماز
# HAM2-830309-053.ham: بهارستاندر اين باغرنگ ها را نفس مي كشمفكر تو راحتي نام تو راو تو را در خيال مي آفرينم تا بخراميكارول آن دفي
# HAM2-830120-086.ham: بهارستاناي گل بهار! اي شكوه زعفراناي گل نرگس!اي شبچراغ درخشان بر زر سرخ!اين چنين دردمندم رها مسازابونواس - ترج
# Query:
# انتخاب سرمربي تيم ملي فوتبال ايران
#
# Results:
# HAM2-821021-047.ham: حيات وحش ايران4 - يوزپلنگ آسيايي
# HAM2-850429-097.ham: واگذاري مراكز تجاري برج ميلاد از ماه آيندهمدير عامل شركت يادمان سازه گفت: قرارداد واگذاري مراكز تجاري برج ميلاد به سرم
# HAM2-840416-147.ham: نگاهداوود كاظميدر صد بالايي از تصادفات به علت استفاده از تلفن همراه به هنگام رانندگي است.
# HAM2-840409-002.ham: نرخ انواع لوازم نقاشي(قيمت ها به هزار ريال)
# HAM2-830309-053.ham: بهارستاندر اين باغرنگ ها را نفس مي كشمفكر تو راحتي نام تو راو تو را در خيال مي آفرينم تا بخراميكارول آن دفي
# HAM2-831005-038.ham: بهارستانحسن حبيب را ديد. گفت: اين درجه به چه يافتي؟گفت: بدان كه من دل سپيد مي كنم و تو كاغذ سياه مي كني.در ذكر حبي
# HAM2-850809-009.ham: عكس روزعكس: مهر / باقر نصيرعلاقه مندان به رشته ورزشي موتورسواري در كوه هاي منطقه شميران تهران، با تجهيزات شخصي به اي
# HAM2-820912-069.ham: بهارستاناز خانه بيرون مي شويمپيش از طلوعو به خانه بازمي آييماز پس غروبگرده ناني مجالمان ندادتا قرص آفتاب را
# HAM2-830513-045.ham: بهارستاناز نوازش جاودانه دستانت، اين خردينه دل مناز شادي،كرانه هايش را گم مي كندو ناگفتني را باز مي گويدرابيند
# HAM2-850720-008.ham: عكس روزعكس: رويترز / گوران توماسويچدو ماهيگير مصري كنار درياچه اي واقع در 210 كيلومتري شمال قاهره، روي قايق خود نماز
